# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from numba import njit
from tqdm.notebook import tqdm
import talib
import pickle
import pystan
import stan_utility

# %%
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, GRU
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import tensorflow_probability as tfp
tfd = tfp.distributions
tfpl = tfp.layers

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
# import multiprocessing
# multiprocessing.set_start_method("fork")

# %% [markdown]
# ## Simulators

# %% [markdown]
# ### Dynamic

# %%
def dynamic_prior(batch_size):
    """
    Generates a random draw from the diffusion model prior.
    """
    v = np.random.gamma(2.5, 1/1.5, (batch_size, 4))
    a = np.random.gamma(4.0, 1/3.0, batch_size)
    ndt = np.random.gamma(1.5, 1/5.0, batch_size)
    hyper_params = np.random.uniform(0.01, 0.1, (batch_size, 6))

    return np.c_[v, a, ndt, hyper_params]


@njit
def context_gen(batch_size, n_obs):
    obs_per_condition = int(n_obs / 4)
    context = np.zeros((batch_size, n_obs), dtype=np.int32)
    x = np.repeat([1, 2, 3, 4], obs_per_condition)
    for i in range(batch_size):
        np.random.shuffle(x)
        context[i] = x
    return context


@njit
def diffusion_trial(v, a, ndt, zr=0.5, dt=0.001, s=1.0, max_iter=1e4):
    """
    Simulates a single reaction time from a simple drift-diffusion process.
    """

    n_iter = 0
    x = a * zr
    c = np.sqrt(dt * s)
    
    while x > 0 and x < a:
        
        # DDM equation
        x += v*dt + c * np.random.randn()
        
        n_iter += 1
        
    rt = n_iter * dt
    return rt+ndt if x > 0 else -(rt+ndt)


@njit
def dynamic_diffusion_process(prior_samples, context, n_obs):
    """
    Performs one run of a dynamic diffusion model process.
    """
    
    params, params_stds = np.split(prior_samples, 2, axis=-1)
    params_t = params
    
    params_t_array = np.zeros((n_obs, params.shape[0]))
    
    # Draw first param combination from prior
    rt = np.zeros(n_obs)
    
    # Iterate over number of trials
    for t in range(n_obs):
        
        # Run diffusion process
        rt[t] = diffusion_trial(params_t[context[t] - 1], params_t[4], params_t[5])
        
        # Store before transition
        params_t_array[t] = params_t
        
        # Transition and ensure non-negative parameters
        params_t = params_t + params_stds * np.random.randn(params.shape[0])
        
        # Constraints
        params_t[0] = min(max(params_t[0], 0.0), 8)
        params_t[1] = min(max(params_t[1], 0.0), 8)
        params_t[2] = min(max(params_t[2], 0.0), 8)
        params_t[3] = min(max(params_t[3], 0.0), 8)
        params_t[4] = min(max(params_t[4], 0.0), 6)
        params_t[5] = min(max(params_t[5], 0.0), 4)
        
    return np.atleast_2d(rt).T, params_t_array, params_stds


@njit
def batch_simulator(prior_samples, context, n_obs):
    
    batch_size = prior_samples.shape[0]
    rt = np.zeros((batch_size, n_obs, 1))
    theta_d = np.zeros((batch_size, n_obs, 6))
    theta_s = np.zeros((batch_size, 6))
    
    for i in range(batch_size):
        rt[i], theta_d[i], theta_s[i] = dynamic_diffusion_process(prior_samples[i], 
                                                                  context[i],
                                                                  n_obs)
    
    return rt, theta_d, theta_s

# %% [markdown]
# ### Static

# %%
@njit
def static_diffusion_process(prior_samples, context, n_obs):
    """
    Performs one run of a static diffusion model process.
    """
    
    params_t, params_stds = np.split(prior_samples, 2, axis=-1)
    
    rt = np.zeros(n_obs)
    
    # Iterate over number of trials
    for t in range(n_obs):
        
        # Run diffusion process
        rt[t] = diffusion_trial(params_t[context[t] - 1], params_t[4], params_t[5])
        
    return np.atleast_2d(rt).T, params_t
    

@njit
def static_batch_simulator(prior_samples, context, n_obs):
    
    batch_size = prior_samples.shape[0]
    rt = np.zeros((batch_size, n_obs, 1))
    theta = np.zeros((batch_size, n_obs, 6))

    for i in range(batch_size):
        rt[i], theta[i] = static_diffusion_process(prior_samples[i], 
                                                         context[i],
                                                         n_obs)
    return rt, theta

# %% [markdown]
# ## Stan modeling

# %%
stan_model = """
data {
  int<lower=0> N;                 
  real<lower=0> rt[N];    
  int<lower=0,upper=1> correct[N];
  int<lower=1,upper=4> context[N];
}

parameters {
  real<lower=0> v[4];
  real<lower=0> a; 
  real<lower=0> ndt;
}

model {
  // Priors
  v ~ gamma(2.5, 1.5);
  a ~ gamma(4.0, 3.0);
  ndt ~ gamma(1.5, 5.0);
  
  for (n in 1:N) {
     if (correct[n] == 1) {
        rt[n] ~ wiener(a, ndt, 0.5, v[context[n]]);
     } 
     else {
        rt[n] ~ wiener(a, ndt, 1 - 0.5, -v[context[n]]);
     }
  }
}
"""

# %%
# # compile stan model
# sm = pystan.StanModel(model_code=stan_model)

# %%
def to_stan(sim_data):
    """
    Convert data from simulator to stan-friendly format.
    """
    rt = sim_data[:, 0]
    context = sim_data[:, 1].astype(np.int32)
    correct = (rt >= 0).astype(np.int32)
    rt = np.abs(rt).astype(np.float32)
    return {'rt': rt, 'correct': correct, 'context': context, 'N': rt.shape[0]}

def loop_stan(data, verbose=True):
    """
    Loop through data and obtain posteriors.
    """
    
    stan_post_samples = []
    for i in range(data.shape[0]):
        data_i = to_stan(data[i])
        ndt_init = data_i['rt'].min() * 0.75
        init = {'ndt': ndt_init}
        fit = sm.sampling(data=data_i, 
                          iter=2000, chains=4, n_jobs=4, init=[init, init, init, init],
                          control=dict(adapt_delta=0.99, max_treedepth=15))
        samples = fit.extract(permuted=True)
        stan_post_samples.append(samples)
        if verbose:
            print(f'Finished estimating data set {i + 1}...')
    return stan_post_samples

# %%
# N_OBS = 800
# batch_size = 100
# prior_draws = dynamic_prior(batch_size)
# context = context_gen(batch_size, N_OBS)
# sim_data, params_t = static_batch_simulator(prior_draws, context, N_OBS)
# stan_post_samples = loop_stan(sim_data)
# pickle.dump(stan_post_samples, open('./stan_posteriors_mine.pkl', 'wb+'))

# %%
# load stan posteriors based on static simulated data
pkl_file = open('stan_posteriors_mine.pkl', 'rb')
stan_post_samples = pickle.load(pkl_file)
pkl_file.close()

# %% [markdown]
# # Amortizers

# %% [markdown]
# ## Network architecture

# %%
class HeteroscedasticNetwork(tf.keras.Model):
    
    def __init__(self, n_params_d):
        super(HeteroscedasticNetwork, self).__init__()
        
        self.preprocessor = Sequential([
            GRU(64, return_sequences=True),
            LSTM(128, return_sequences=True),
            Dense(128, activation='selu', kernel_initializer='lecun_normal'),
        ])
        
        self.dynamic_predictor = Sequential([
            Dense(64, activation='selu', kernel_initializer='lecun_normal'),
            tf.keras.layers.Dense(tfpl.MultivariateNormalTriL.params_size(n_params_d)),
            tfpl.MultivariateNormalTriL(n_params_d)
        ])
        
    def call(self, x):
        """
        Forward pass through the model.
        """
        
        # Obtain representation
        rep = self.preprocessor(x)
        
        # Predict dynamic stuff
        preds_dyn = self.dynamic_predictor(rep)
     
        return preds_dyn

# %% [markdown]
# ## Loss

# %%
def nll(y_true, y_pred):
    return tf.reduce_mean(-y_pred.log_prob(y_true))

# %% [markdown]
# ## Epoch helper

# %%
def train_epoch(network, optimizer, batch_size, steps_per_epoch, p_bar):
    
    losses = []
    for step in range(1, steps_per_epoch+1):
        with tf.GradientTape() as tape:
        
            # Simulate from model
            prior_draws = dynamic_prior(batch_size)
            context = context_gen(batch_size, N_OBS)
            x_t, params_t, _= batch_simulator(prior_draws, context, N_OBS)
            net_in = tf.concat((x_t, context[:, :, np.newaxis]), axis=-1)
            pred_params_t = network(net_in)

            # Loss dynamic and static
            loss_d = nll(params_t, pred_params_t)
            
            total_loss = loss_d
        g = tape.gradient(total_loss, network.trainable_variables)
        optimizer.apply_gradients(zip(g, network.trainable_variables))
        losses.append(total_loss.numpy())

        # Update progress bar
        p_bar.set_postfix_str("Ep: {},Step {},Loss D: {:.3f} Running Loss: {:.3f}"
                              .format(ep, step, loss_d.numpy(), np.mean(losses)))
        p_bar.update(1)

# %% [markdown]
# ## Training

# %%
N_OBS = 800
batch_size = 16
epochs = 50
steps_per_epoch = 1000
learning_rate = 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate)
network = HeteroscedasticNetwork(6)

# %%
# change learning rate
epochs = 50
learning_rate = 0.00001
optimizer = tf.keras.optimizers.Adam(learning_rate)

# %%
for ep in range(1, epochs+1):
    with tqdm(total=steps_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
        train_epoch(network, optimizer, batch_size, steps_per_epoch, p_bar)
# Out:
# Training epoch 1:   0%|          | 0/1000 [00:00<?, ?it/s]
# 2022-02-09 18:14:57.459936: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 195.31MiB (rounded to 204800000)requested by op Fill
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-02-09 18:14:57.460305: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2022-02-09 18:14:57.460346: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 707, Chunks in use: 707. 176.8KiB allocated for chunks. 176.8KiB in use in bin. 7.0KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460371: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 20, Chunks in use: 19. 10.2KiB allocated for chunks. 9.5KiB in use in bin. 9.5KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460392: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 19, Chunks in use: 13. 30.8KiB allocated for chunks. 20.2KiB in use in bin. 19.0KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460414: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 36, Chunks in use: 24. 100.2KiB allocated for chunks. 68.5KiB in use in bin. 65.0KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460434: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 11, Chunks in use: 10. 56.5KiB allocated for chunks. 52.2KiB in use in bin. 44.8KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460455: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 7, Chunks in use: 6. 85.8KiB allocated for chunks. 73.8KiB in use in bin. 41.8KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460474: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 206, Chunks in use: 196. 3.93MiB allocated for chunks. 3.74MiB in use in bin. 3.58MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460492: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 34, Chunks in use: 34. 1.33MiB allocated for chunks. 1.33MiB in use in bin. 1.12MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460513: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 341, Chunks in use: 341. 32.68MiB allocated for chunks. 32.68MiB in use in bin. 29.36MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460535: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 161, Chunks in use: 160. 29.45MiB allocated for chunks. 29.29MiB in use in bin. 17.64MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460555: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 52, Chunks in use: 51. 16.72MiB allocated for chunks. 16.23MiB in use in bin. 14.92MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460576: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 2, Chunks in use: 1. 1.43MiB allocated for chunks. 781.2KiB in use in bin. 625.0KiB client-requested in use in bin.
# 2022-02-09 18:14:57.460598: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 235, Chunks in use: 232. 426.62MiB allocated for chunks. 421.12MiB in use in bin. 413.43MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460619: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 32, Chunks in use: 30. 82.23MiB allocated for chunks. 75.93MiB in use in bin. 54.13MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460640: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 59, Chunks in use: 58. 385.78MiB allocated for chunks. 380.82MiB in use in bin. 371.70MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460659: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 341, Chunks in use: 338. 3.70GiB allocated for chunks. 3.68GiB in use in bin. 3.21GiB client-requested in use in bin.
# 2022-02-09 18:14:57.460678: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 60, Chunks in use: 59. 1.15GiB allocated for chunks. 1.13GiB in use in bin. 665.28MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460700: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 3, Chunks in use: 2. 117.19MiB allocated for chunks. 78.12MiB in use in bin. 78.12MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460725: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 2, Chunks in use: 1. 203.86MiB allocated for chunks. 117.19MiB in use in bin. 117.19MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460747: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 2, Chunks in use: 1. 376.90MiB allocated for chunks. 195.31MiB in use in bin. 195.31MiB client-requested in use in bin.
# 2022-02-09 18:14:57.460765: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-02-09 18:14:57.460784: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 195.31MiB was 128.00MiB, Chunk State:
# 2022-02-09 18:14:57.460813: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 181.59MiB | Requested Size: 39.06MiB | in_use: 0 | bin_num: 19, prev:   Size: 1.83MiB | Requested Size: 1.83MiB | in_use: 1 | bin_num: -1
# 2022-02-09 18:14:57.460827: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 2659188736
# 2022-02-09 18:14:57.460845: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc000000000 of size 11520000 next 3173
# 2022-02-09 18:14:57.460859: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc000afc800 of size 11520000 next 1691
# 2022-02-09 18:14:57.460871: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0015f9000 of size 11520000 next 2059
# 2022-02-09 18:14:57.460884: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0020f5800 of size 40960000 next 1844
# 2022-02-09 18:14:57.460896: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc004805800 of size 11520000 next 2026
# 2022-02-09 18:14:57.460909: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc005302000 of size 11520000 next 1806
# 2022-02-09 18:14:57.460921: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc005dfe800 of size 11520000 next 1721
# 2022-02-09 18:14:57.460934: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0068fb000 of size 11520000 next 2652
# 2022-02-09 18:14:57.460946: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0073f7800 of size 11520000 next 2323
# 2022-02-09 18:14:57.460960: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc007ef4000 of size 18978816 next 2657
# 2022-02-09 18:14:57.460973: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00910d800 of size 6720000 next 1606
# 2022-02-09 18:14:57.460985: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc009776200 of size 11520000 next 498
# 2022-02-09 18:14:57.460998: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00a272a00 of size 11520000 next 2411
# 2022-02-09 18:14:57.461010: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00ad6f200 of size 11520000 next 761
# 2022-02-09 18:14:57.461023: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00b86ba00 of size 11520000 next 130
# 2022-02-09 18:14:57.461036: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00c368200 of size 18978816 next 384
# 2022-02-09 18:14:57.461048: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00d581a00 of size 6720000 next 118
# 2022-02-09 18:14:57.461061: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc00dbea400 of size 40960000 next 2101
# 2022-02-09 18:14:57.461073: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0102fa400 of size 11520000 next 1089
# 2022-02-09 18:14:57.461085: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc010df6c00 of size 11520000 next 2693
# 2022-02-09 18:14:57.461097: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0118f3400 of size 6720000 next 1509
# 2022-02-09 18:14:57.461120: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc011f5be00 of size 8320000 next 2319
# 2022-02-09 18:14:57.461133: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc01274b200 of size 11520000 next 357
# 2022-02-09 18:14:57.461145: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc013247a00 of size 11520000 next 2567
# 2022-02-09 18:14:57.461158: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc013d44200 of size 11520000 next 416
# 2022-02-09 18:14:57.461171: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc014840a00 of size 1920000 next 1335
# 2022-02-09 18:14:57.461183: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc014a15600 of size 11520000 next 2066
# 2022-02-09 18:14:57.461195: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc015511e00 of size 1920000 next 3069
# 2022-02-09 18:14:57.461207: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0156e6a00 of size 1920000 next 1037
# 2022-02-09 18:14:57.461220: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0158bb600 of size 11520000 next 885
# 2022-02-09 18:14:57.461233: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0163b7e00 of size 320000 next 188
# 2022-02-09 18:14:57.461245: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc016406000 of size 1920000 next 2547
# 2022-02-09 18:14:57.461258: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0165dac00 of size 11520000 next 89
# 2022-02-09 18:14:57.461270: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0170d7400 of size 1920000 next 3279
# 2022-02-09 18:14:57.461283: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0172ac000 of size 1920000 next 2253
# 2022-02-09 18:14:57.461295: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc017480c00 of size 11520000 next 319
# 2022-02-09 18:14:57.461307: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc017f7d400 of size 11520000 next 2282
# 2022-02-09 18:14:57.461319: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc018a79c00 of size 11520000 next 494
# 2022-02-09 18:14:57.461335: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc019576400 of size 14720000 next 1863
# 2022-02-09 18:14:57.461348: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc01a380000 of size 11520000 next 2788
# 2022-02-09 18:14:57.461360: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc01ae7c800 of size 40960000 next 87
# 2022-02-09 18:14:57.461372: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc01d58c800 of size 11520000 next 2191
# 2022-02-09 18:14:57.461385: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc01e089000 of size 11520000 next 2474
# 2022-02-09 18:14:57.461397: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc01eb85800 of size 11520000 next 179
# 2022-02-09 18:14:57.461409: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc01f682000 of size 11520000 next 3021
# 2022-02-09 18:14:57.461422: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02017e800 of size 1920000 next 2019
# 2022-02-09 18:14:57.461434: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc020353400 of size 11520000 next 1922
# 2022-02-09 18:14:57.461446: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc020e4fc00 of size 1920000 next 375
# 2022-02-09 18:14:57.461459: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc021024800 of size 1920000 next 1719
# 2022-02-09 18:14:57.461471: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0211f9400 of size 11520000 next 595
# 2022-02-09 18:14:57.461484: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc021cf5c00 of size 1920000 next 2417
# 2022-02-09 18:14:57.461496: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc021eca800 of size 11520000 next 353
# 2022-02-09 18:14:57.461510: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0229c7000 of size 1920000 next 634
# 2022-02-09 18:14:57.461523: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc022b9bc00 of size 11520000 next 476
# 2022-02-09 18:14:57.461535: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc023698400 of size 1920000 next 241
# 2022-02-09 18:14:57.461548: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02386d000 of size 1920000 next 2133
# 2022-02-09 18:14:57.461560: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc023a41c00 of size 11520000 next 3116
# 2022-02-09 18:14:57.461572: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02453e400 of size 1920000 next 440
# 2022-02-09 18:14:57.461585: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc024713000 of size 11520000 next 1755
# 2022-02-09 18:14:57.461597: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02520f800 of size 1920000 next 3080
# 2022-02-09 18:14:57.461609: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0253e4400 of size 11520000 next 1603
# 2022-02-09 18:14:57.461622: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc025ee0c00 of size 1920000 next 615
# 2022-02-09 18:14:57.461634: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0260b5800 of size 1920000 next 2138
# 2022-02-09 18:14:57.461646: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02628a400 of size 11520000 next 1366
# 2022-02-09 18:14:57.461659: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc026d86c00 of size 1920000 next 2356
# 2022-02-09 18:14:57.461671: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc026f5b800 of size 11520000 next 3070
# 2022-02-09 18:14:57.461683: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc027a58000 of size 1920000 next 2993
# 2022-02-09 18:14:57.461696: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc027c2cc00 of size 11520000 next 2628
# 2022-02-09 18:14:57.461708: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc028729400 of size 1920000 next 2251
# 2022-02-09 18:14:57.461721: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0288fe000 of size 1920000 next 2293
# 2022-02-09 18:14:57.461733: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc028ad2c00 of size 11520000 next 38
# 2022-02-09 18:14:57.461745: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0295cf400 of size 1920000 next 279
# 2022-02-09 18:14:57.461758: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0297a4000 of size 11520000 next 1443
# 2022-02-09 18:14:57.461770: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02a2a0800 of size 1920000 next 1732
# 2022-02-09 18:14:57.461782: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02a475400 of size 11520000 next 648
# 2022-02-09 18:14:57.461794: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02af71c00 of size 1920000 next 812
# 2022-02-09 18:14:57.461806: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02b146800 of size 1920000 next 2422
# 2022-02-09 18:14:57.461819: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02b31b400 of size 11520000 next 1409
# 2022-02-09 18:14:57.461831: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02be17c00 of size 1920000 next 1050
# 2022-02-09 18:14:57.461844: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02bfec800 of size 11520000 next 1465
# 2022-02-09 18:14:57.461856: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02cae9000 of size 320000 next 1056
# 2022-02-09 18:14:57.461869: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02cb37200 of size 1920000 next 448
# 2022-02-09 18:14:57.461882: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02cd0be00 of size 11520000 next 1868
# 2022-02-09 18:14:57.461896: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02d808600 of size 1920000 next 1601
# 2022-02-09 18:14:57.461908: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02d9dd200 of size 1920000 next 1931
# 2022-02-09 18:14:57.461921: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02dbb1e00 of size 11520000 next 1808
# 2022-02-09 18:14:57.461933: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02e6ae600 of size 11520000 next 1750
# 2022-02-09 18:14:57.461948: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02f1aae00 of size 11520000 next 224
# 2022-02-09 18:14:57.461960: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc02fca7600 of size 11520000 next 2906
# 2022-02-09 18:14:57.461973: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0307a3e00 of size 11520000 next 143
# 2022-02-09 18:14:57.461986: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0312a0600 of size 6720000 next 2554
# 2022-02-09 18:14:57.461998: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc031909000 of size 6720000 next 1999
# 2022-02-09 18:14:57.462010: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc031f71a00 of size 11520000 next 3100
# 2022-02-09 18:14:57.462023: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc032a6e200 of size 6720000 next 2360
# 2022-02-09 18:14:57.462035: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0330d6c00 of size 6720000 next 1749
# 2022-02-09 18:14:57.462048: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03373f600 of size 6720000 next 2121
# 2022-02-09 18:14:57.462061: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc033da8000 of size 7360000 next 2304
# 2022-02-09 18:14:57.462074: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0344ace00 of size 11520000 next 2829
# 2022-02-09 18:14:57.462086: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc034fa9600 of size 11520000 next 3302
# 2022-02-09 18:14:57.462098: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc035aa5e00 of size 11520000 next 1728
# 2022-02-09 18:14:57.462111: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0365a2600 of size 11520000 next 2439
# 2022-02-09 18:14:57.462123: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03709ee00 of size 6720000 next 2433
# 2022-02-09 18:14:57.462136: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc037707800 of size 8960000 next 1986
# 2022-02-09 18:14:57.462149: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc037f93000 of size 13760000 next 573
# 2022-02-09 18:14:57.462162: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc038cb2600 of size 11520000 next 1182
# 2022-02-09 18:14:57.462174: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0397aee00 of size 11520000 next 2563
# 2022-02-09 18:14:57.462186: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03a2ab600 of size 11520000 next 2415
# 2022-02-09 18:14:57.462199: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03ada7e00 of size 11520000 next 3211
# 2022-02-09 18:14:57.462211: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03b8a4600 of size 11520000 next 1450
# 2022-02-09 18:14:57.462223: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03c3a0e00 of size 6720000 next 998
# 2022-02-09 18:14:57.462236: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03ca09800 of size 10560000 next 3256
# 2022-02-09 18:14:57.462249: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03d41ba00 of size 3200000 next 879
# 2022-02-09 18:14:57.462262: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03d728e00 of size 20480000 next 508
# 2022-02-09 18:14:57.462274: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03eab0e00 of size 11520000 next 1108
# 2022-02-09 18:14:57.462287: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc03f5ad600 of size 11520000 next 292
# 2022-02-09 18:14:57.462299: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0400a9e00 of size 1920000 next 893
# 2022-02-09 18:14:57.462311: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04027ea00 of size 11520000 next 883
# 2022-02-09 18:14:57.462324: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc040d7b200 of size 1920000 next 2800
# 2022-02-09 18:14:57.462336: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc040f4fe00 of size 11520000 next 1430
# 2022-02-09 18:14:57.462349: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc041a4c600 of size 1920000 next 2148
# 2022-02-09 18:14:57.462361: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc041c21200 of size 1920000 next 2627
# 2022-02-09 18:14:57.462373: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc041df5e00 of size 11520000 next 426
# 2022-02-09 18:14:57.462386: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0428f2600 of size 1920000 next 1390
# 2022-02-09 18:14:57.462398: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc042ac7200 of size 11520000 next 1768
# 2022-02-09 18:14:57.462410: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0435c3a00 of size 1920000 next 1859
# 2022-02-09 18:14:57.462422: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc043798600 of size 1920000 next 1889
# 2022-02-09 18:14:57.462435: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04396d200 of size 11520000 next 839
# 2022-02-09 18:14:57.462447: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc044469a00 of size 1920000 next 1529
# 2022-02-09 18:14:57.462459: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04463e600 of size 11520000 next 2629
# 2022-02-09 18:14:57.462472: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04513ae00 of size 1920000 next 2149
# 2022-02-09 18:14:57.462484: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04530fa00 of size 11520000 next 1568
# 2022-02-09 18:14:57.462496: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc045e0c200 of size 1920000 next 2584
# 2022-02-09 18:14:57.462508: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc045fe0e00 of size 1920000 next 1442
# 2022-02-09 18:14:57.462521: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0461b5a00 of size 11520000 next 3104
# 2022-02-09 18:14:57.462534: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc046cb2200 of size 1920000 next 1424
# 2022-02-09 18:14:57.462546: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc046e86e00 of size 1920000 next 1866
# 2022-02-09 18:14:57.462559: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04705ba00 of size 11520000 next 1666
# 2022-02-09 18:14:57.462572: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc047b58200 of size 12160000 next 947
# 2022-02-09 18:14:57.462584: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0486f0e00 of size 11520000 next 1140
# 2022-02-09 18:14:57.462597: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0491ed600 of size 11520000 next 2887
# 2022-02-09 18:14:57.462609: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc049ce9e00 of size 11520000 next 1646
# 2022-02-09 18:14:57.462621: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04a7e6600 of size 11520000 next 3187
# 2022-02-09 18:14:57.462634: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04b2e2e00 of size 11520000 next 3026
# 2022-02-09 18:14:57.462649: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04bddf600 of size 11520000 next 3280
# 2022-02-09 18:14:57.462661: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04c8dbe00 of size 11520000 next 2257
# 2022-02-09 18:14:57.462674: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04d3d8600 of size 11520000 next 1537
# 2022-02-09 18:14:57.462686: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04ded4e00 of size 11520000 next 828
# 2022-02-09 18:14:57.462698: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04e9d1600 of size 11520000 next 641
# 2022-02-09 18:14:57.462711: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04f4cde00 of size 11520000 next 1546
# 2022-02-09 18:14:57.462723: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc04ffca600 of size 18978816 next 1284
# 2022-02-09 18:14:57.462736: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0511e3e00 of size 11520000 next 3161
# 2022-02-09 18:14:57.462748: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc051ce0600 of size 11520000 next 2280
# 2022-02-09 18:14:57.462760: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0527dce00 of size 11520000 next 1948
# 2022-02-09 18:14:57.462773: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0532d9600 of size 11520000 next 3031
# 2022-02-09 18:14:57.462785: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc053dd5e00 of size 11520000 next 2688
# 2022-02-09 18:14:57.462797: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0548d2600 of size 11520000 next 1644
# 2022-02-09 18:14:57.462810: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0553cee00 of size 17920000 next 781
# 2022-02-09 18:14:57.462822: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0564e5e00 of size 6720000 next 930
# 2022-02-09 18:14:57.462835: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc056b4e800 of size 6720000 next 987
# 2022-02-09 18:14:57.462847: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0571b7200 of size 6720000 next 2065
# 2022-02-09 18:14:57.462860: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc05781fc00 of size 6720000 next 2623
# 2022-02-09 18:14:57.462873: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc057e88600 of size 90880000 next 2442
# 2022-02-09 18:14:57.462886: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc05d533e00 of size 1920000 next 966
# 2022-02-09 18:14:57.462898: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc05d708a00 of size 11520000 next 2369
# 2022-02-09 18:14:57.462910: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc05e205200 of size 1920000 next 2469
# 2022-02-09 18:14:57.462926: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc05e3d9e00 of size 204800000 next 471
# 2022-02-09 18:14:57.462939: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06a729e00 of size 11520000 next 539
# 2022-02-09 18:14:57.462951: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06b226600 of size 11520000 next 2347
# 2022-02-09 18:14:57.462964: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06bd22e00 of size 11520000 next 2550
# 2022-02-09 18:14:57.462976: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06c81f600 of size 11520000 next 2462
# 2022-02-09 18:14:57.462989: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06d31be00 of size 11520000 next 2576
# 2022-02-09 18:14:57.463001: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06de18600 of size 1920000 next 1478
# 2022-02-09 18:14:57.463013: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06dfed200 of size 11520000 next 2352
# 2022-02-09 18:14:57.463027: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06eae9a00 of size 1920000 next 2599
# 2022-02-09 18:14:57.463040: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06ecbe600 of size 11520000 next 227
# 2022-02-09 18:14:57.463053: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06f7bae00 of size 1920000 next 2386
# 2022-02-09 18:14:57.463065: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc06f98fa00 of size 11520000 next 2659
# 2022-02-09 18:14:57.463077: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07048c200 of size 1920000 next 2868
# 2022-02-09 18:14:57.463090: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc070660e00 of size 11520000 next 1661
# 2022-02-09 18:14:57.463102: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc07115d600 of size 3840000 next 1551
# 2022-02-09 18:14:57.463115: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc071506e00 of size 11520000 next 1989
# 2022-02-09 18:14:57.463127: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc072003600 of size 1920000 next 1517
# 2022-02-09 18:14:57.463140: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0721d8200 of size 11520000 next 433
# 2022-02-09 18:14:57.463152: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc072cd4a00 of size 1920000 next 2830
# 2022-02-09 18:14:57.463164: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc072ea9600 of size 11520000 next 1275
# 2022-02-09 18:14:57.463176: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0739a5e00 of size 1920000 next 1305
# 2022-02-09 18:14:57.463189: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc073b7aa00 of size 1920000 next 2879
# 2022-02-09 18:14:57.463201: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc073d4f600 of size 11520000 next 1381
# 2022-02-09 18:14:57.463214: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07484be00 of size 1920000 next 3190
# 2022-02-09 18:14:57.463226: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc074a20a00 of size 11520000 next 2338
# 2022-02-09 18:14:57.463239: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07551d200 of size 2240000 next 2959
# 2022-02-09 18:14:57.463252: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc075740000 of size 11520000 next 1555
# 2022-02-09 18:14:57.463264: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07623c800 of size 1920000 next 94
# 2022-02-09 18:14:57.463277: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc076411400 of size 1920000 next 544
# 2022-02-09 18:14:57.463289: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0765e6000 of size 11520000 next 142
# 2022-02-09 18:14:57.463301: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0770e2800 of size 1920000 next 1926
# 2022-02-09 18:14:57.463314: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0772b7400 of size 11520000 next 1355
# 2022-02-09 18:14:57.463326: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc077db3c00 of size 2240000 next 1125
# 2022-02-09 18:14:57.463339: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc077fd6a00 of size 11520000 next 2289
# 2022-02-09 18:14:57.463352: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc078ad3200 of size 1920000 next 91
# 2022-02-09 18:14:57.463364: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc078ca7e00 of size 1920000 next 381
# 2022-02-09 18:14:57.463376: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc078e7ca00 of size 11520000 next 876
# 2022-02-09 18:14:57.463388: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc079979200 of size 1920000 next 1683
# 2022-02-09 18:14:57.463401: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc079b4de00 of size 11520000 next 938
# 2022-02-09 18:14:57.463413: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07a64a600 of size 320000 next 2395
# 2022-02-09 18:14:57.463426: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07a698800 of size 1920000 next 1949
# 2022-02-09 18:14:57.463438: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07a86d400 of size 11520000 next 174
# 2022-02-09 18:14:57.463451: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07b369c00 of size 1920000 next 1815
# 2022-02-09 18:14:57.463463: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07b53e800 of size 1920000 next 996
# 2022-02-09 18:14:57.463475: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07b713400 of size 11520000 next 2995
# 2022-02-09 18:14:57.463488: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07c20fc00 of size 11520000 next 1896
# 2022-02-09 18:14:57.463500: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07cd0c400 of size 11520000 next 2353
# 2022-02-09 18:14:57.463513: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07d808c00 of size 11520000 next 878
# 2022-02-09 18:14:57.463525: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07e305400 of size 11520000 next 2408
# 2022-02-09 18:14:57.463538: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07ee01c00 of size 11520000 next 2685
# 2022-02-09 18:14:57.463550: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc07f8fe400 of size 11520000 next 2811
# 2022-02-09 18:14:57.463562: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0803fac00 of size 11520000 next 638
# 2022-02-09 18:14:57.463574: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc080ef7400 of size 11520000 next 694
# 2022-02-09 18:14:57.463587: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0819f3c00 of size 11520000 next 2167
# 2022-02-09 18:14:57.463599: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0824f0400 of size 11520000 next 2825
# 2022-02-09 18:14:57.463611: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc082fecc00 of size 11520000 next 3267
# 2022-02-09 18:14:57.463624: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc083ae9400 of size 11520000 next 2625
# 2022-02-09 18:14:57.463636: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0845e5c00 of size 11520000 next 190
# 2022-02-09 18:14:57.463649: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0850e2400 of size 11520000 next 1680
# 2022-02-09 18:14:57.463661: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc085bdec00 of size 11520000 next 1479
# 2022-02-09 18:14:57.463673: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0866db400 of size 11520000 next 3018
# 2022-02-09 18:14:57.463686: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0871d7c00 of size 11520000 next 3298
# 2022-02-09 18:14:57.463698: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc087cd4400 of size 11520000 next 3289
# 2022-02-09 18:14:57.463710: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0887d0c00 of size 11520000 next 1576
# 2022-02-09 18:14:57.463722: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0892cd400 of size 11520000 next 2893
# 2022-02-09 18:14:57.463735: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc089dc9c00 of size 11520000 next 1787
# 2022-02-09 18:14:57.463747: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08a8c6400 of size 1920000 next 769
# 2022-02-09 18:14:57.463759: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08aa9b000 of size 11520000 next 2325
# 2022-02-09 18:14:57.463772: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08b597800 of size 1920000 next 2915
# 2022-02-09 18:14:57.463786: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08b76c400 of size 1920000 next 1437
# 2022-02-09 18:14:57.463799: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08b941000 of size 11520000 next 3054
# 2022-02-09 18:14:57.463812: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08c43d800 of size 1920000 next 370
# 2022-02-09 18:14:57.463824: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08c612400 of size 11520000 next 2850
# 2022-02-09 18:14:57.463837: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08d10ec00 of size 1920000 next 2719
# 2022-02-09 18:14:57.463849: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08d2e3800 of size 11520000 next 299
# 2022-02-09 18:14:57.463861: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08dde0000 of size 1920000 next 3177
# 2022-02-09 18:14:57.463873: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08dfb4c00 of size 1920000 next 1294
# 2022-02-09 18:14:57.463886: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08e189800 of size 11520000 next 1570
# 2022-02-09 18:14:57.463898: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08ec86000 of size 1920000 next 2461
# 2022-02-09 18:14:57.463911: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08ee5ac00 of size 11520000 next 1132
# 2022-02-09 18:14:57.463923: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08f957400 of size 1920000 next 1282
# 2022-02-09 18:14:57.463936: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc08fb2c000 of size 11520000 next 2486
# 2022-02-09 18:14:57.463948: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc090628800 of size 1920000 next 1258
# 2022-02-09 18:14:57.463960: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0907fd400 of size 1920000 next 1299
# 2022-02-09 18:14:57.463973: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0909d2000 of size 11520000 next 688
# 2022-02-09 18:14:57.463985: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0914ce800 of size 1920000 next 1241
# 2022-02-09 18:14:57.463998: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0916a3400 of size 11520000 next 1791
# 2022-02-09 18:14:57.464010: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc09219fc00 of size 320000 next 2953
# 2022-02-09 18:14:57.464022: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0921ede00 of size 1920000 next 3258
# 2022-02-09 18:14:57.464035: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0923c2a00 of size 11520000 next 3062
# 2022-02-09 18:14:57.464047: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc092ebf200 of size 1920000 next 2272
# 2022-02-09 18:14:57.464059: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc093093e00 of size 1920000 next 509
# 2022-02-09 18:14:57.464073: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc093268a00 of size 190412288 next 18446744073709551615
# 2022-02-09 18:14:57.464086: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 2147483648
# 2022-02-09 18:14:57.464099: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa000000 of size 86528 next 3086
# 2022-02-09 18:14:57.464131: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa015200 of size 115200 next 2327
# 2022-02-09 18:14:57.464145: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa031400 of size 204800 next 2440
# 2022-02-09 18:14:57.464157: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa063400 of size 86528 next 1689
# 2022-02-09 18:14:57.464170: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa078600 of size 115200 next 3145
# 2022-02-09 18:14:57.464182: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa094800 of size 204800 next 3071
# 2022-02-09 18:14:57.464197: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa0c6800 of size 86528 next 2459
# 2022-02-09 18:14:57.464209: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa0dba00 of size 115200 next 2998
# 2022-02-09 18:14:57.464222: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa0f7c00 of size 204800 next 614
# 2022-02-09 18:14:57.464234: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa129c00 of size 86528 next 1675
# 2022-02-09 18:14:57.464247: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa13ee00 of size 224000 next 1265
# 2022-02-09 18:14:57.464260: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa175900 of size 19200 next 754
# 2022-02-09 18:14:57.464272: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa17a400 of size 19200 next 2560
# 2022-02-09 18:14:57.464285: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa17ef00 of size 6912 next 512
# 2022-02-09 18:14:57.464297: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0aa180a00 of size 12288 next 2099
# 2022-02-09 18:14:57.464310: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa183a00 of size 19200 next 2919
# 2022-02-09 18:14:57.464325: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa188500 of size 134400 next 2641
# 2022-02-09 18:14:57.464338: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa1a9200 of size 19200 next 102
# 2022-02-09 18:14:57.464350: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa1add00 of size 115200 next 315
# 2022-02-09 18:14:57.464363: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa1c9f00 of size 176128 next 1019
# 2022-02-09 18:14:57.464375: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa1f4f00 of size 19200 next 833
# 2022-02-09 18:14:57.464387: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa1f9a00 of size 67328 next 2006
# 2022-02-09 18:14:57.464400: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa20a100 of size 67328 next 2838
# 2022-02-09 18:14:57.464413: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa21a800 of size 146944 next 430
# 2022-02-09 18:14:57.464426: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa23e600 of size 86528 next 2600
# 2022-02-09 18:14:57.464438: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa253800 of size 19200 next 228
# 2022-02-09 18:14:57.464450: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa258300 of size 19200 next 1867
# 2022-02-09 18:14:57.464463: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0aa25ce00 of size 19200 next 1129
# 2022-02-09 18:14:57.464475: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa261900 of size 19200 next 1177
# 2022-02-09 18:14:57.464487: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa266400 of size 153600 next 984
# 2022-02-09 18:14:57.464500: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa28bc00 of size 204800 next 1187
# 2022-02-09 18:14:57.464513: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa2bdc00 of size 201728 next 2720
# 2022-02-09 18:14:57.464526: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa2ef000 of size 115200 next 2362
# 2022-02-09 18:14:57.464538: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0aa30b200 of size 5205504 next 1138
# 2022-02-09 18:14:57.464551: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa802000 of size 1843200 next 1134
# 2022-02-09 18:14:57.464564: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aa9c4000 of size 2918400 next 2398
# 2022-02-09 18:14:57.464579: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aac8c800 of size 98304 next 1104
# 2022-02-09 18:14:57.464593: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aaca4800 of size 32768 next 1714
# 2022-02-09 18:14:57.464607: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aacac800 of size 131072 next 690
# 2022-02-09 18:14:57.464620: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aaccc800 of size 320256 next 86
# 2022-02-09 18:14:57.464633: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aad1ab00 of size 320000 next 135
# 2022-02-09 18:14:57.464645: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aad68d00 of size 320000 next 1602
# 2022-02-09 18:14:57.464658: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0aadb6f00 of size 697600 next 542
# 2022-02-09 18:14:57.464671: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aae61400 of size 11520000 next 327
# 2022-02-09 18:14:57.464683: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0ab95dc00 of size 2400000 next 3282
# 2022-02-09 18:14:57.464696: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0abba7b00 of size 800000 next 2946
# 2022-02-09 18:14:57.464709: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0abc6b000 of size 320000 next 1560
# 2022-02-09 18:14:57.464721: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0abcb9200 of size 320000 next 47
# 2022-02-09 18:14:57.464734: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0abd07400 of size 18403328 next 2615
# 2022-02-09 18:14:57.464747: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0ace94400 of size 86528 next 2037
# 2022-02-09 18:14:57.464760: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7fc0acea9600 of size 19200 next 455
# 2022-02-09 18:14:57.464772: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aceae100 of size 19200 next 1427
# 2022-02-09 18:14:57.464785: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aceb2c00 of size 22528 next 511
# 2022-02-09 18:14:57.464797: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0aceb8400 of size 19200 next 1564
# 2022-02-09 18:14:57.464810: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0acebcf00 of size 67328 next 2950
# 2022-02-09 18:14:57.464825: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0acecd600 of size 82944 next 1029
# 2022-02-09 18:14:57.464838: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0acee1a00 of size 204800 next 1266
# 2022-02-09 18:14:57.464850: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0acf13a00 of size 86528 next 2216
# 2022-02-09 18:14:57.464863: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0acf28c00 of size 115200 next 1895
# 2022-02-09 18:14:57.464875: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7fc0acf44e00 of size 115200 next 1758
# ...
# 2022-02-09 18:14:57.484267: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2551808 totalling 2.43MiB
# 2022-02-09 18:14:57.484271: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2560000 totalling 2.44MiB
# 2022-02-09 18:14:57.484275: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2585600 totalling 2.47MiB
# 2022-02-09 18:14:57.484278: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2720000 totalling 2.59MiB
# 2022-02-09 18:14:57.484282: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2761728 totalling 2.63MiB
# 2022-02-09 18:14:57.484285: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2764800 totalling 2.64MiB
# 2022-02-09 18:14:57.484289: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 2918400 totalling 5.57MiB
# 2022-02-09 18:14:57.484292: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3200000 totalling 3.05MiB
# 2022-02-09 18:14:57.484296: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 3276800 totalling 6.25MiB
# 2022-02-09 18:14:57.484299: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3320320 totalling 3.17MiB
# 2022-02-09 18:14:57.484303: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 3584000 totalling 6.84MiB
# 2022-02-09 18:14:57.484306: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3645440 totalling 3.48MiB
# 2022-02-09 18:14:57.484310: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 43 Chunks of size 6720000 totalling 275.57MiB
# 2022-02-09 18:14:57.484314: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 6767104 totalling 6.45MiB
# 2022-02-09 18:14:57.484318: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 7040000 totalling 40.28MiB
# 2022-02-09 18:14:57.484321: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7301888 totalling 6.96MiB
# 2022-02-09 18:14:57.484325: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7307264 totalling 6.97MiB
# 2022-02-09 18:14:57.484328: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7333632 totalling 6.99MiB
# 2022-02-09 18:14:57.484332: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7360000 totalling 7.02MiB
# 2022-02-09 18:14:57.484336: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7557888 totalling 7.21MiB
# 2022-02-09 18:14:57.484339: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7782400 totalling 7.42MiB
# 2022-02-09 18:14:57.484411: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8320000 totalling 7.93MiB
# 2022-02-09 18:14:57.484415: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8385280 totalling 8.00MiB
# 2022-02-09 18:14:57.484419: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8435200 totalling 8.04MiB
# 2022-02-09 18:14:57.484423: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8499200 totalling 8.11MiB
# 2022-02-09 18:14:57.484426: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8704000 totalling 8.30MiB
# 2022-02-09 18:14:57.484430: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8830464 totalling 8.42MiB
# 2022-02-09 18:14:57.484433: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8956928 totalling 8.54MiB
# 2022-02-09 18:14:57.484437: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 8960000 totalling 8.54MiB
# 2022-02-09 18:14:57.484441: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 9600000 totalling 9.16MiB
# 2022-02-09 18:14:57.484444: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 9920000 totalling 9.46MiB
# 2022-02-09 18:14:57.484448: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 10560000 totalling 20.14MiB
# 2022-02-09 18:14:57.484451: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 11161600 totalling 10.64MiB
# 2022-02-09 18:14:57.484455: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 11200000 totalling 10.68MiB
# 2022-02-09 18:14:57.484459: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 291 Chunks of size 11520000 totalling 3.12GiB
# 2022-02-09 18:14:57.484463: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 11622400 totalling 11.08MiB
# 2022-02-09 18:14:57.484466: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12134400 totalling 11.57MiB
# 2022-02-09 18:14:57.484470: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 12160000 totalling 34.79MiB
# 2022-02-09 18:14:57.484474: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12205056 totalling 11.64MiB
# 2022-02-09 18:14:57.484478: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12462080 totalling 11.88MiB
# 2022-02-09 18:14:57.484481: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12693248 totalling 12.10MiB
# 2022-02-09 18:14:57.484485: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 12800000 totalling 48.83MiB
# 2022-02-09 18:14:57.484489: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12833792 totalling 12.24MiB
# 2022-02-09 18:14:57.484493: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 12846080 totalling 12.25MiB
# 2022-02-09 18:14:57.484496: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13066240 totalling 12.46MiB
# 2022-02-09 18:14:57.484500: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13209600 totalling 12.60MiB
# 2022-02-09 18:14:57.484504: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13363200 totalling 12.74MiB
# 2022-02-09 18:14:57.484508: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13418496 totalling 12.80MiB
# 2022-02-09 18:14:57.484511: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13465600 totalling 12.84MiB
# 2022-02-09 18:14:57.484515: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13688832 totalling 13.05MiB
# 2022-02-09 18:14:57.484519: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 13760000 totalling 26.25MiB
# 2022-02-09 18:14:57.484523: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 13824000 totalling 13.18MiB
# 2022-02-09 18:14:57.484597: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 14076416 totalling 13.42MiB
# 2022-02-09 18:14:57.484601: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 14215424 totalling 13.56MiB
# 2022-02-09 18:14:57.484605: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 14445056 totalling 13.78MiB
# 2022-02-09 18:14:57.484608: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 14720000 totalling 14.04MiB
# 2022-02-09 18:14:57.484612: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 14948864 totalling 14.26MiB
# 2022-02-09 18:14:57.484616: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 15356160 totalling 14.64MiB
# 2022-02-09 18:14:57.484620: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 15944448 totalling 15.21MiB
# 2022-02-09 18:14:57.484623: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 15986176 totalling 15.25MiB
# 2022-02-09 18:14:57.484627: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 16086528 totalling 15.34MiB
# 2022-02-09 18:14:57.484631: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 16320000 totalling 15.56MiB
# 2022-02-09 18:14:57.484634: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 16486400 totalling 15.72MiB
# 2022-02-09 18:14:57.484638: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 16640000 totalling 15.87MiB
# 2022-02-09 18:14:57.484642: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 17280000 totalling 16.48MiB
# 2022-02-09 18:14:57.484646: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 17920000 totalling 17.09MiB
# 2022-02-09 18:14:57.484650: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 18403328 totalling 17.55MiB
# 2022-02-09 18:14:57.484654: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 18558976 totalling 17.70MiB
# 2022-02-09 18:14:57.484657: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 18560000 totalling 17.70MiB
# 2022-02-09 18:14:57.484661: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 18657536 totalling 17.79MiB
# 2022-02-09 18:14:57.484665: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 18880000 totalling 18.00MiB
# 2022-02-09 18:14:57.484668: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 18904832 totalling 18.03MiB
# 2022-02-09 18:14:57.484672: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 18978816 totalling 54.30MiB
# 2022-02-09 18:14:57.484676: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 19353600 totalling 18.46MiB
# 2022-02-09 18:14:57.484680: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 19520000 totalling 18.62MiB
# 2022-02-09 18:14:57.484683: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 19840000 totalling 18.92MiB
# 2022-02-09 18:14:57.484687: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 19976192 totalling 19.05MiB
# 2022-02-09 18:14:57.484691: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 20111616 totalling 19.18MiB
# 2022-02-09 18:14:57.484694: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 20114432 totalling 19.18MiB
# 2022-02-09 18:14:57.484698: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 20172800 totalling 19.24MiB
# 2022-02-09 18:14:57.484702: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 26 Chunks of size 20480000 totalling 507.81MiB
# 2022-02-09 18:14:57.484706: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 20889600 totalling 19.92MiB
# 2022-02-09 18:14:57.484710: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 21129472 totalling 20.15MiB
# 2022-02-09 18:14:57.484775: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 22112256 totalling 21.09MiB
# 2022-02-09 18:14:57.484779: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 22151680 totalling 21.12MiB
# 2022-02-09 18:14:57.484783: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 5 Chunks of size 22400000 totalling 106.81MiB
# 2022-02-09 18:14:57.484787: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 22621696 totalling 21.57MiB
# 2022-02-09 18:14:57.484791: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 5 Chunks of size 22720000 totalling 108.34MiB
# 2022-02-09 18:14:57.484794: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 40960000 totalling 78.12MiB
# 2022-02-09 18:14:57.484798: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 122880000 totalling 117.19MiB
# 2022-02-09 18:14:57.484802: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 204800000 totalling 195.31MiB
# 2022-02-09 18:14:57.484806: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 6.13GiB
# 2022-02-09 18:14:57.484809: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 6968836096 memory_limit_: 6968836096 available bytes: 0 curr_region_allocation_bytes_: 8589934592
# 2022-02-09 18:14:57.484816: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                      6968836096
# InUse:                      6577779712
# MaxInUse:                   6831310592
# NumAllocs:                    16465442
# MaxAllocSize:                317452288
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-02-09 18:14:57.484924: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ************************************__**************************************************************
# 2022-02-09 18:14:57.491186: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at constant_op.cc:175 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[51200000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_2794/3235858490.py in <module>
#       1 for ep in range(1, epochs+1):
#       2     with tqdm(total=steps_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:
# ----> 3         train_epoch(network, optimizer, batch_size, steps_per_epoch, p_bar)
#
# /tmp/ipykernel_2794/3678829318.py in train_epoch(network, optimizer, batch_size, steps_per_epoch, p_bar)
#      16
#      17             total_loss = loss_d
# ---> 18         g = tape.gradient(total_loss, network.trainable_variables)
#      19         optimizer.apply_gradients(zip(g, network.trainable_variables))
#      20         losses.append(total_loss.numpy())
#
# ~/anaconda3/envs/cogModel/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1082                           for x in nest.flatten(output_gradients)]
#    1083
# -> 1084     flat_grad = imperative_grad.imperative_grad(
#    1085         self._tape,
#    1086         flat_targets,
#
# ~/anaconda3/envs/cogModel/lib/python3.9/site-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      69         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      70
# ---> 71   return pywrap_tfe.TFE_Py_TapeGradient(
#      72       tape._tape,  # pylint: disable=protected-access
#      73       target,
#
# ~/anaconda3/envs/cogModel/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py in _zeros(shape, dtype)
#     697     else:
#     698       value = 0
# --> 699     cached = _fast_fill(value, shape, dtype)
#     700     ctx.zeros_cache().put(cache_key, cached)
#     701   return cached
#
# ~/anaconda3/envs/cogModel/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py in _fast_fill(value, shape, dtype)
#     669
#     670 def _fast_fill(value, shape, dtype):
# --> 671   return array_ops.fill(
#     672       constant_op.constant(shape, dtype=dtypes.int32),
#     673       constant_op.constant(value, dtype=dtype))
#
# ~/anaconda3/envs/cogModel/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~/anaconda3/envs/cogModel/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7105 def raise_from_not_ok_status(e, name):
#    7106   e.message += (" name: " + name if name is not None else "")
# -> 7107   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7108
#    7109
#
# ResourceExhaustedError: OOM when allocating tensor with shape[51200000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Fill]

# %%
network.save_weights('checkpoints/dynamic_seventh')

# %%
# network.load_weights('checkpoints/dynamic_seventh')

# %% [markdown]
# # Evalutation

# %%
# load stan posteriors based on static simulated data
pkl_file = open('stan_posteriors_mine.pkl', 'rb')
stan_post_samples = pickle.load(pkl_file)
pkl_file.close()

# %%
def plot_dynamic_posteriors(dynamic_posterior, par_labels, par_names, 
                           ground_truths=None, color_pred='#884da3'):
    """
    Inspects the dynamic posterior given a single data set. Assumes six dynamic paramters.
    """
    
    assert len(dynamic_posterior.shape) == 3, "Dynamic posterior should be 3-dimensional!" 
    assert ground_truths is None or len(ground_truths.shape) == 2,'Ground truths should be 2-dimensional!'
    assert dynamic_posterior.shape[0] == 1, "Function assumes dynamics posterior for a single data set!" 
        
    means = dynamic_posterior.mean()[0]
    std = dynamic_posterior.stddev()[0]
    
    sigma_factors = [1]
    alphas = [0.6]
    
    time = np.arange(x_t.shape[1])
    f, axarr = plt.subplots(2, 3, figsize=(18, 8))
    for i, ax in enumerate(axarr.flat):
        
        ax.plot(time, means[:, i], color=color_pred, label='Posterior Mean')
        for sigma_factor, alpha in zip(sigma_factors, alphas):
            ci_upper = means[:, i] + sigma_factor * std[:, i]
            ci_lower = means[:, i] - sigma_factor * std[:, i]
            ax.fill_between(time, ci_upper, ci_lower, color=color_pred, alpha=alpha)
        if ground_truths is not None:
            ax.plot(time, ground_truths[:, i], color='black', linestyle='dashed', label='True Dynamic', lw=2)
        sns.despine(ax=ax)
        ax.grid(alpha=0.15)
        ax.set_xlabel('Time (t)')
        ax.set_ylabel('Parameter value ({})'.format(par_names[i]), fontsize=12)
        ax.set_title(par_labels[i] + ' ({})'.format(par_names[i]), fontsize=12)
        
        if i == 0:
            f.legend()
    
    f.tight_layout()

# %%
# dynamic simulation
n_test = 6
prior_draws = dynamic_prior(n_test)
context_draws = context_gen(n_test, N_OBS)
x_t, params_t, params_s = batch_simulator(prior_draws, context_draws.astype(np.int32), N_OBS)
x_in = np.concatenate((x_t, context_draws[:, :, np.newaxis]), axis=-1)
x_in.shape

# %%
# static simulation
N_OBS = 800
batch_size = 100
prior_draws = dynamic_prior(batch_size)
context = context_gen(batch_size, N_OBS)
x_t, params_t = static_batch_simulator(prior_draws, context, N_OBS)
x_in = np.concatenate((x_t, context[:, :, np.newaxis]), axis=-1)
x_in.shape
# Out:
# (100, 800, 2)

# %%
which = 3
dynamic_posterior = network(x_in[which:(which+1)])
ground_truths = params_t[which]
par_labels = ['Drift rate 1', 'Drift rate 2', 'Drift rate 3', 'Drift rate 4', 'Threshold', 'Non-decision time']
par_names = [r'$v_1$', r'$v_2$', r'$v_3$', r'$v_3$', r'$a$', r'$\tau$']
plot_dynamic_posteriors(dynamic_posterior, par_labels,  par_names, ground_truths)

# %% [markdown]
# ### Compare standard deviation

# %%
dynamic_post_sd = np.zeros((100, 6))
stan_sd = np.zeros((100, 6))

for j in range(100):
    dynamic_posterior = network(x_in[j:(j+1)])
    dynamic_post_sd[j] = np.array(dynamic_posterior.stddev()[0, 119])
    
    v = stan_post_samples[j]['v']
    a = stan_post_samples[j]['a']
    ndt = stan_post_samples[j]['ndt']

    stan_posterior = np.c_[v, a, ndt]
    stan_sd[j] = stan_posterior.std(axis=0)

# %%
dynamic_post_sd.mean(axis=0)
# Out:
# array([0.54342707, 0.53596197, 0.51817734, 0.51077772, 0.21970387,
#        0.05097286])

# %%
dynamic_post_sd.mean(axis=0)
# Out:
# array([0.54378812, 0.53588107, 0.51546005, 0.51225108, 0.20992537,
#        0.05364887])

# %%
stan_sd.mean(axis=0)
# Out:
# array([0.16393563, 0.16122814, 0.16628025, 0.16238552, 0.02915448,
#        0.00377554])
